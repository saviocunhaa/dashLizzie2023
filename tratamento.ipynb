# %%
import matplotlib.pyplot as plt
import mysql.connector
import numpy as np
import pandas as pd
import streamlit as st

# %%
conexao = mysql.connector.connect(host='sql496.main-hosting.eu', database='u459129097_lizz',
                                  user='u459129097_visio', password='visiosolucaowebliz13')

cursor = conexao.cursor()
if conexao.is_connected():
    print('conexão ok')

queryPedido = ('SELECT * FROM pedidos')
queryCliente = ('SELECT * FROM clientes')
queryItensPedidos = ('SELECT * FROM itens_pedidos')
queryProduto = ('SELECT * FROM produtos')
queryVendedor = ('SELECT * FROM vendedores')

dfPedido = pd.read_sql(queryPedido, conexao)
dfCliente = pd.read_sql(queryCliente, conexao)
dfItensPedidos = pd.read_sql(queryItensPedidos, conexao)
dfProduto = pd.read_sql(queryProduto, conexao)
dfVendedor = pd.read_sql(queryVendedor, conexao)
# Out:
# conexão ok
# C:\Users\Sávio Cunha\AppData\Local\Temp\ipykernel_11780\1994564415.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfPedido = pd.read_sql(queryPedido, conexao)
# C:\Users\Sávio Cunha\AppData\Local\Temp\ipykernel_11780\1994564415.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfCliente = pd.read_sql(queryCliente, conexao)
# C:\Users\Sávio Cunha\AppData\Local\Temp\ipykernel_11780\1994564415.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfItensPedidos = pd.read_sql(queryItensPedidos, conexao)
# C:\Users\Sávio Cunha\AppData\Local\Temp\ipykernel_11780\1994564415.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfProduto = pd.read_sql(queryProduto, conexao)
# C:\Users\Sávio Cunha\AppData\Local\Temp\ipykernel_11780\1994564415.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfVendedor = pd.read_sql(queryVendedor, conexao)

# %%
dfCliente['Month'] = dfCliente[''].apply(lambda x: x.month)
dfCliente['Year'] = dfCliente[''].apply(lambda x: x.year)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Sávio Cunha\Documents\GitHub\Lizzie\venv\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\Sávio Cunha\Documents\GitHub\Lizzie\venv\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Sávio Cunha\Documents\GitHub\Lizzie\venv\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dfCliente['Month'] = dfCliente[''].apply(lambda x: x.month)
#       2 dfCliente['Year'] = dfCliente[''].apply(lambda x: x.year)
#
# File c:\Users\Sávio Cunha\Documents\GitHub\Lizzie\venv\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\Sávio Cunha\Documents\GitHub\Lizzie\venv\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: ''

# %%
display(dfPedido)
# Out:
#      id_pedido  id_cliente  id_vendedor  total_pedido
# 0            1           1            4       1189.80  \
# 1            8           2            4        427.50
# 2            9           3            4        694.00
# 3           10           4            4        202.50
# 4           12           5            4        394.00
# ..         ...         ...          ...           ...
# 752        807         260           10       1887.30
# 753        808         100           10       5133.10
# 754        809          83            6       6027.30
# 755        810         110            6       2002.70
# 756        811          72            6       1715.85
#
#                                             obs_pedido obs_cancelamento
# 0    Dividir pedido nas cores Masculino e Feminino....             None  \
# 1    REF 15 - 01 ROSA + 01 AZUL + 01 AMARELO\r\nREF...             None
# 2    REF 14: TODOS ESTAMPADOS\r\n\r\nTODO O PEDIDO ...             None
# 3    REF 26 - SÓ FEMININO\r\nREF. 13 - METADE MASC ...             None
# 4      APLICAR DESCONTO DE 42,00 REF. A TABELA ANTIGA.             None
# ..                                                 ...              ...
# 752                                            urgente             None
# 753  OBS:CLIENTE QUER:\r\nREF.004- 3 ROSA BB, 3 AZU...             None
# 754                                    1-FATURAR JUNHO             None
# 755  1-FATURAR URGENTE - INAUGURAÇÃO DE OUTRA LOJA\...             None
# 756                                    1-FATURAR JUNHO             None
#
#                            obs_entrega data_entrega
# 0                                        2017-07-13  \
# 1                                        2017-09-25
# 2                                        2017-09-25
# 3                                        2017-10-02
# 4                                        2017-08-04
# ..                                 ...          ...
# 752                                ...         None
# 753                                ...         None
# 754                    1-FATURAR JUNHO         None
# 755  1-FATURAR URGENTE\r\n\r\n\r\n\r\n         None
# 756                    1-FATURAR JUNHO         None
#
#                       forma_pag  ped_desconto  status         data_pedido
# 0                         30/60           0.0       4 2017-08-26 00:12:51
# 1        30 DIAS BOLETO S/ NOTA           0.0       4 2017-09-09 11:26:01
# 2    Boleto 20 /40 dias s/ Nota           0.0       4 2017-09-09 17:00:55
# 3                Boleto 30 dias           0.0       4 2017-09-12 14:26:49
# 4        30 DIAS BOLETO S/ NOTA           0.0       4 2017-09-19 16:59:48
# ..                          ...           ...     ...                 ...
# 752                     A VISTA           6.0       2 2023-05-09 13:23:20
# 753                30/60/90/120           0.0       2 2023-05-11 12:55:46
# 754                30/60/90/120           0.0       2 2023-05-22 11:17:00
# 755                30/60/90/120           0.0       2 2023-05-23 20:59:27
# 756                    30/60/90           0.0       2 2023-05-23 21:33:25
#
# [757 rows x 12 columns]

# %%
(dfPedido["status"].values == 4).()
# Out:
# 681

# %%
dfPedido.groupby(by="Month").sum(numeric_only=True)[["total_pedido"]].sort_values("Month")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dfPedido.groupby(by="Month").sum(numeric_only=True)[["total_pedido"]].sort_values("Month")
#
# NameError: name 'dfPedido' is not defined
